# %% [markdown]
# # <center> Exploring Data About Colleges </center>

# %% [markdown]
# This is a markdown cell. Type something here!

# %% [markdown]
# ...and **Code cells** (where you can type R code, see next cell).

# %%
# Press the Run button or Ctrl+Return (or Cmnd+Return for mac)
print("Lizi luvs MfA LA")

#you can also use a code cell as calculator
3*7+9

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# The data set we will be exploring today is part of <a href="https://skewthescript.org/data-science-challenge">the After the Exam Data Science Challenge</a> (a collaboration of Skew the Script, Data Science 4 Everyone, North Carolina State Data Science Academy, and [CourseKata](coursekata.org)). **Please do not circulate.**
#
# </div>

# %% [markdown]
# # Which colleges are worth the price of admission?
#
# Does college pay off? We'll use from the US Department of Education's <a href="https://collegescorecard.ed.gov/data/">College Scorecard Database</a> to answer that question.
#
# In this notebook, you'll use R to create scatterplots and fit simple linear regression models to explore how certain colleges might be better investments than others.
#
# **Run the code cell below to set up the Jupyter notebook. The data set we're using is called `colleges`.**

# %%
# run this code to load coursekata's library of R functions
suppressPackageStartupMessages({
    library(coursekata)
})

options(repr.matrix.max.cols = 1000)

# This command grabs data from a csv file stored in google docs
# and puts it in a data frame called college_dat
colleges <- read.csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQfYL84GVFzetxkmEsuMLCcN4QeWZikYEYGNr4ZbV4_dRLAUb_HPr021e0FAb-5sK4AQaHNbe3M7JW4/pub?gid=616759312&single=true&output=csv')

# This prints the first 6 rows of colleges
head(colleges)

# %% [markdown]
# ## 1.0: Get to Know the Dataset (`colleges`)
#
# The US Department of Education's <a href="https://collegescorecard.ed.gov/data/">College Scorecard Database</a> shows various metrics of cost, enrollment, size, student debt, student demographics, and alumni success. It describes almost every University, college, community college, trade school, and certificate program in the United States. The data is current as of the 2020-2021 school year.
#
# The vertical columns of the dataframe are called `variables`, and their elements are called `values`. For example, the variable `city` has values `Normal`, `Birmingham`, `Montgomery`, `Huntsville`, etc.
#
# The horizontal rows of the dataframe are called `observations`. For example, the first observation is `Alabama A & M University`, which is located in `AL` (Alabama), in the city of `Normal`, and has a median student debt of `$15,250`. For this dataframe, each observation describes a specific college.

# %% [markdown]
# **1.1:** Take a look at your <a href="https://docs.google.com/document/d/e/2PACX-1vQiqj-kw_eeGhZ3cupwpwMPO3tHbHOCRawvP7XWrUdUDsLCZw8T71Buoe6jfiKzB8d8z9Y2O_3Fo32O/pub">handout</a> which lists all the variables and a brief description for `colleges`. What variables are you interested in or curious about? Are there any variables that you are surprised to see? Any variables that you think should be in the dataset?

# %% [markdown]
# **1.2:** Lets look at some of the colleges you discussed in the opening question. Run the code below to print out the row for Idaho State University (go Bengals!)
#
# Then let's edit the code to look at other colleges.

# %%
filter(colleges, name == "Idaho State University")

# %% [markdown]
# **1.3:** Sometimes looking up a particular college is hard because of all the variation in how we can write the name (e.g., Idaho State University versus Idaho State or ISU). So we can also filter by state (abbreviation) to look up exactly the way a college is named in this data set.

# %%
filter(colleges, state == "ID")

# %% [markdown]
# **1.4:** One of the variables we are going to focus on is `default_rate`.
#
# Our goal today is to think about *which colleges are worth the price of admission?* One of the variables we are going to focus on is `default_rate`.
# >`default_rate` is the percent of school's borrowers in default on student loans (from recent cohorts). Includes students who graduate, transfer, or dropout.
# - Why might we look at `default rate`?
# - Why might this question be relvant for *students*?
#
# ✏️ ...

# %% [markdown]
# **1.5:** What does a low default rate mean? What does a high default rate mean?
#
# ✏️ ...

# %% [markdown]
# ## 2.0: What Variables Are Related to `default rate`? *The `select()` Command*
#
# What variables are you curious about? Let's take closer look. Run the code below to use the `select()` command.

# %%
# here's how to select a few variables to show from the colleges dataset
# add in default_rate and then run. 
select(colleges, name)

# %% [markdown]
# **2.1:** Add other variables to the `select()` function in the code cell above (you can refer to the <a href="https://docs.google.com/document/d/e/2PACX-1vQiM-BanJDDimx02JdYyx_WFkrkwUgHMvFKwXJo3FoISulnRsn459E4Kff9ZD_lM5pWrfilRWxSylQ4/pub">handout</a>).
#
# (If you want to arrange the data frame in order by a certain variable, you can also pipe on, `%>%` the `arrange()` function. We can do an example together.)

# %% [markdown]
# **2.2:** Start to look for patterns or relationships in the data.
#
# - What do you notice about colleges with really low default rates or really high default rates?
# - Is there anything that surprises you?
# - What questions do you have?
#
# ✏️ ...

# %% [markdown]
# **2.3:** What other variables might help us predict the loan default rate of a university? What relationship do you think they have? Write a **hypothesis** for one of your variables. An example is shown below.
#
# > **Example hypothesis:** `avg_cost` might be important for predicting `default_rate`. I think colleges with *higher* `avg_cost` will have a *higher* `default_rate`.
#
# We can write this hypothesis as a word equation **default_rate = avg_cost + other stuff**
#
# 📝 On the back of your handout, write some hypotheses that you want to explore as word equations. Sketch what you expect those relationships to look like. 📝

# %% [markdown]
# ## 3.0: Explore Your Hypothesis *The `gf_point()` Command*

# %% [markdown]
# **3.1:** Let's create a scatter plot to explore our hypothesis. Edit the code below, adding variable names -- `default_rate` and the predictor variable you picked for your hypothesis.
#
# We need to add our variables into the code below to create a scatter plot. Add your variables -- we want to model `default_rate` and *some other variable that you

# %%
# add your variables to the code below to explore your hypothesis
gf_point( ~ , data = colleges)

# %% [markdown]
# **3.6:** What does your scatter plot tell you about your hypothesis? How does your hypothesis compare to your neighbors?
#
# ✏️ ...

# %% [markdown]
# **3.7:** Keep playing! Can you find the best predictor for a college's `default_rate`?

# %% [markdown]
# ## 4.0: *Modeling* `default_rate`
# Can you create a function to help us predict `default_rate`?

# %% [markdown]
# **4.1:** What do you think a *good* model for your data should look like? How would you decide if a model is good or not?
#
# ✏️ ...

# %% [markdown]
# **4.2:** You can tinker with *y-intercept* and *slope*. Edit and run the code below to try to plot a line that could model the data.
#
# Try it out in the code cell below.

# %%
gf_point(default_rate ~ avg_cost, data = colleges) %>%
  gf_abline(intercept = 70, slope = 0, color = "blue")

# %% [markdown]
# **4.3:** Maybe you want to write your own function or try non-linear functions. You can create a custom function and add it to your graph.
#
# Try it out in the code cell below.

# %%
# create your own function
my_function <- function(X){ .10x^2 }

gf_point(default_rate ~ avg_cost, data = colleges, color = "orange") %>%
  gf_function(my_function, color = "purple")

# %% [markdown]
# **4.4:** Or maybe you just want to graph the best-fitting linear function to our data. *Can you use any of the code commands above to try to find the equation of the best-fitting linear function?

# %%
gf_point(default_rate ~ avg_cost, data = colleges, color = "orange") %>%
  gf_lm()

# %% [markdown]
# # Obligatory Plug: CourseKata Gates Foundation High School Stats Teacher Fellowship!
#
# <img src="https://cdn.prod.website-files.com/6789c29ed0bff3679af53e2c/69d684e2f277d6aab4c0d6f8_HSfellowshipFlyer.png" width = 80%>
#
# [Learn More](https://www.coursekata.org/news-announcements/2026-27-coursekata-fellowship-for-high-school-teachers)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59b6ca27-b1c0-4000-9d61-7dbd635c3df1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
